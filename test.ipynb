# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 5050 Laptop GPU

# %%
from ultralytics import YOLO
model = YOLO('yolo26s.pt')   # downloads on first run
model.info()
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\khage\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# YOLO26s summary: 260 layers, 10,009,784 parameters, 0 gradients, 22.8 GFLOPs
# (260, 10009784, 0, 22.838476800000002)

# %%
import os
classes = os.listdir('data_folder/datasets/phase1/food101/images')
print(f'Food-101 classes: {len(classes)}')
# Out:
# Food-101 classes: 101

# %%
import glob
bbox_files = glob.glob('data_folder/datasets/phase2/uec256/**/*.txt', recursive=True)
print(f'Annotation files found: {len(bbox_files)}')
# Out:
# Annotation files found: 258

# %%
masks = glob.glob('data_folder/datasets/phase2/foodseg103/**/*mask*.png', recursive=True)
print(f'Mask files found: {len(masks)}')
# Out:
# Mask files found: 0

# %%
from pycocotools.coco import COCO
coco = COCO('data_folder/datasets/phase2/foodrecog2022/raw_data/public_training_set_release_2.0/annotations.json')
print(f'Images: {len(coco.imgs)}')
print(f'Categories: {len(coco.cats)}')
print(f'Annotations: {len(coco.anns)}')
# Out:
# loading annotations into memory...
# Done (t=2.85s)
# creating index...
# index created!
# Images: 39962
# Categories: 498
# Annotations: 76491

# %%
imgs = glob.glob('data_folder/datasets/phase2/unimib/**/*.jpg', recursive=True)
print(f'UNIMIB images: {len(imgs)}')
# Out:
# UNIMIB images: 961

# %%
import pandas as pd

df = pd.read_csv('data_folder/datasets/phase1/chinese/food_class.csv')
df.drop(columns=['Chinese Name'], inplace=True)
df.head()
# Out:
#    List No.             English Name
# 0         0                Mapo Tofu
# 1         1  Home style sauteed Tofu
# 2         2               Fried Tofu
# 3         3                Bean curd
# 4         4              Stinky tofu

# %%
df.to_csv('data_folder/datasets/phase1/chinese/food_class.csv', index=False)
