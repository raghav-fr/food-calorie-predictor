# %%
from ultralytics import YOLO
model = YOLO('yolo26s.pt')   # downloads on first run
model.info()
# Out:
# YOLO26s summary: 260 layers, 10,009,784 parameters, 0 gradients, 22.8 GFLOPs
# (260, 10009784, 0, 22.838476800000002)

# %%
import os
dirs = [
  'datasets/phase1/food101',
  'datasets/phase1/chinese',
  'datasets/phase1/mafood',
  'datasets/phase2/uec256',
  'datasets/phase2/foodrecog2022',
  'datasets/phase2/foodseg103',
  'datasets/phase2/unimib',
  'merged/phase1/images/train',
  'merged/phase1/images/val',
  'merged/phase1/labels/train',
  'merged/phase1/labels/val',
  'merged/phase2/images/train',
  'merged/phase2/images/val',
  'merged/phase2/labels/train',
  'merged/phase2/labels/val',
  'runs/phase1', 'runs/phase2',
  'weights', 'exports', 'logs'
]
for d in dirs:
  os.makedirs(d, exist_ok=True)
print('All dirs created.')
# Out:
# All dirs created.
